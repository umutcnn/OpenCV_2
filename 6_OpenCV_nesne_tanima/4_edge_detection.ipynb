# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt #resimler üzerinde çizim yapmak için
#çizim yapılan resimleri kaydetmek için
# %matplotlib inline

# %%
#köpegin yuzu 
img=cv2.imread('pug_2.png')
plt.imshow(face)

# %%
#canny kenar algoritması
edges= cv2.Canny(image=face,threshold1=127,threshold2=127)
plt.imshow(edges)

# %%
#köpegin yuzu 
#canny kenar bulma algoritması
edges= cv2.Canny(image=face,threshold1=0,threshold2=255)
plt.imshow(edges)

# %%
blurred_img=cv2.blur(img,ksize=(5,5))
edges= cv2.Canny(image=blurred_img,threshold1=100,threshold2=90)
plt.imshow(edges)
