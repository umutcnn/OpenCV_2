# %%
import cv2

# %%
img= cv2.imread('aircraft.jpg')
plt.imshow(img)

# %%
#bgr olan renk sıralamasını rgb yapalım
img= cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
#rgb olan görseli hsv yapalım
img= cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imshow(img)

# %%
#rgb olan görseli hls yapalım
img= cv2.cvtColor(img,cv2.COLOR_BGR2HLS)
plt.imshow(img)
